# %% [markdown]
# # Vertical FL Example

# %%
# !pip install metaflow==2.4.1
# !pip install ray
# Out:
# Requirement already satisfied: metaflow==2.4.1 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (2.4.1)
# Requirement already satisfied: click>=7.0 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from metaflow==2.4.1) (8.0.1)
# Requirement already satisfied: pylint in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from metaflow==2.4.1) (2.15.0)
# Requirement already satisfied: boto3 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from metaflow==2.4.1) (1.24.63)
# Requirement already satisfied: requests in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from metaflow==2.4.1) (2.28.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from boto3->metaflow==2.4.1) (0.6.0)
# Requirement already satisfied: botocore<1.28.0,>=1.27.63 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from boto3->metaflow==2.4.1) (1.27.63)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from boto3->metaflow==2.4.1) (1.0.1)
# Requirement already satisfied: dill>=0.2 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from pylint->metaflow==2.4.1) (0.3.5.1)
# Requirement already satisfied: typing-extensions>=3.10.0 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from pylint->metaflow==2.4.1) (4.0.0)
# Requirement already satisfied: isort<6,>=4.2.5 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from pylint->metaflow==2.4.1) (5.10.1)
# Requirement already satisfied: platformdirs>=2.2.0 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from pylint->metaflow==2.4.1) (2.5.2)
# Requirement already satisfied: astroid<=2.14.0-dev0,>=2.12.4 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from pylint->metaflow==2.4.1) (2.12.5)
# Requirement already satisfied: tomli>=1.1.0 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from pylint->metaflow==2.4.1) (2.0.1)
# Requirement already satisfied: tomlkit>=0.10.1 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from pylint->metaflow==2.4.1) (0.11.4)
# Requirement already satisfied: mccabe<0.8,>=0.6 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from pylint->metaflow==2.4.1) (0.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from requests->metaflow==2.4.1) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from requests->metaflow==2.4.1) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from requests->metaflow==2.4.1) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from requests->metaflow==2.4.1) (2.1.1)
# Requirement already satisfied: lazy-object-proxy>=1.4.0 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from astroid<=2.14.0-dev0,>=2.12.4->pylint->metaflow==2.4.1) (1.7.1)
# Requirement already satisfied: wrapt<2,>=1.11 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from astroid<=2.14.0-dev0,>=2.12.4->pylint->metaflow==2.4.1) (1.14.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from botocore<1.28.0,>=1.27.63->boto3->metaflow==2.4.1) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.28.0,>=1.27.63->boto3->metaflow==2.4.1) (1.16.0)
# Requirement already satisfied: ray in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (2.0.0)
# Requirement already satisfied: pyyaml in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from ray) (6.0)
# Requirement already satisfied: frozenlist in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from ray) (1.3.1)
# Requirement already satisfied: numpy>=1.16 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from ray) (1.21.0)
# Requirement already satisfied: protobuf<4.0.0,>=3.15.3 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from ray) (3.19.5)
# Requirement already satisfied: grpcio<=1.43.0,>=1.28.1 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from ray) (1.34.1)
# Requirement already satisfied: filelock in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from ray) (3.8.0)
# Requirement already satisfied: aiosignal in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from ray) (1.2.0)
# Requirement already satisfied: requests in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from ray) (2.28.1)
# Requirement already satisfied: attrs in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from ray) (22.1.0)
# Requirement already satisfied: jsonschema in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from ray) (4.14.0)
# Requirement already satisfied: click<=8.0.4,>=7.0 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from ray) (8.0.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from ray) (1.0.4)
# Requirement already satisfied: virtualenv in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from ray) (20.16.4)
# Requirement already satisfied: six>=1.5.2 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from grpcio<=1.43.0,>=1.28.1->ray) (1.16.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from jsonschema->ray) (0.18.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from jsonschema->ray) (1.3.10)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from jsonschema->ray) (5.9.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from requests->ray) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from requests->ray) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from requests->ray) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from requests->ray) (2022.6.15)
# Requirement already satisfied: platformdirs<3,>=2.4 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from virtualenv->ray) (2.5.2)
# Requirement already satisfied: distlib<1,>=0.3.5 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from virtualenv->ray) (0.3.6)
# Requirement already satisfied: zipp>=3.1.0 in /home/pfoley1/anaconda3/envs/py3.8/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema->ray) (3.8.1)

# %%
from openfl.experimental.interface import FLSpec, Aggregator, Collaborator
from openfl.experimental.runtime import LocalRuntime
from openfl.experimental.placement import aggregator, collaborator

# %%
class VerticalFlow(FLSpec):

    @aggregator
    def start(self):
        self.collaborators = self.runtime.collaborators
        self.round = 0
        self.next_collaborator = ['Portland']
        self.next(self.custom_task_portland, foreach='next_collaborator')

    @collaborator
    def custom_task_portland(self):
        print(f'Collaborator {self.input}: performing custom task')
        self.result = 0
        self.next(self.gather_portland_results)

    @aggregator
    def gather_portland_results(self,inputs):
        self.results = []
        self.results.append(inputs[0].result)
        self.next_collaborator = ['Seattle']
        self.next(self.custom_task_seattle, foreach='next_collaborator', exclude=['results'])

    @collaborator
    def custom_task_seattle(self):
        print(f'Collaborator {self.input}: performing custom task')
        self.result = 1
        self.next(self.gather_seattle_results)

    @aggregator
    def gather_seattle_results(self,inputs):
        self.results.append(inputs[0].result)
        self.next_collaborator = ['Chandler']
        self.next(self.custom_task_chandler, foreach='next_collaborator', exclude=['results'])

    @collaborator
    def custom_task_chandler(self):
        print(f'Collaborator {self.input}: performing custom task')
        self.result = 2
        self.next(self.gather_chandler_results)

    @aggregator
    def gather_chandler_results(self,inputs):
        self.results.append(inputs[0].result)
        self.next_collaborator = ['Bangalore']
        self.next(self.custom_task_bangalore, foreach='next_collaborator', exclude=['results'])

    @collaborator
    def custom_task_bangalore(self):
        print(f'Collaborator {self.input}: performing custom task')
        self.result = 3
        self.next(self.gather_bangalore_results)

    @aggregator
    def gather_bangalore_results(self,inputs):
        self.results.append(inputs[0].result)
        self.next(self.combine)

    @aggregator
    def combine(self):
        print(f'The results from each of the collaborators are: {self.results}')
        print(f'Their average = {sum(self.results) / len(self.results)}')
        self.round += 1
        if self.round < 10:
            print()
            print(f'Starting round {self.round}...')
            self.next_collaborator = ['Portland']
            self.next(self.custom_task_portland,foreach='next_collaborator')
        else:
            self.next(self.end)

    @aggregator
    def end(self):
        print(f'This is the end of the flow')
# Out:
# Aggregator step "start" registered
# Collaborator step "custom_task_portland" registered
# Aggregator step "gather_portland_results" registered
# Collaborator step "custom_task_seattle" registered
# Aggregator step "gather_seattle_results" registered
# Collaborator step "custom_task_chandler" registered
# Aggregator step "gather_chandler_results" registered
# Collaborator step "custom_task_bangalore" registered
# Aggregator step "gather_bangalore_results" registered
# Aggregator step "combine" registered
# Aggregator step "end" registered

# %%
# Setup participants
aggregator = Aggregator()
aggregator.private_attributes = {}

# Setup collaborators with private attributes
collaborator_names = ['Portland', 'Seattle', 'Chandler', 'Bangalore']
collaborators = [Collaborator(name=name) for name in collaborator_names]

local_runtime = LocalRuntime(
    aggregator=aggregator, collaborators=collaborators)
print(f'Local runtime collaborators = {local_runtime._collaborators}')

vflow = VerticalFlow(checkpoint=True)
vflow.runtime = local_runtime
vflow.run()
print(f'Reached end of the flow with collaborator results = {vflow.results}')
# Out:
# Local runtime collaborators = {'Portland': <openfl.experimental.interface.participants.Collaborator object at 0x7fb1fe9db9a0>, 'Seattle': <openfl.experimental.interface.participants.Collaborator object at 0x7fb1fe9db7f0>, 'Chandler': <openfl.experimental.interface.participants.Collaborator object at 0x7fb1fe9db5e0>, 'Bangalore': <openfl.experimental.interface.participants.Collaborator object at 0x7fb1fe9db700>}
# Created flow VerticalFlow
#
# Calling start
# Saving data artifacts for start
# Saved data artifacts for start
# Sending state from aggregator to collaborators
# Next function = gather_portland_results
#
# Calling gather_portland_results
# Saving data artifacts for gather_portland_results
# Saved data artifacts for gather_portland_results
# Sending state from aggregator to collaborators
# Next function = gather_seattle_results
#
# Calling gather_seattle_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_portland in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_portland
# (wrapper pid=21844) Collaborator Portland: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_portland
# (wrapper pid=21844) Saved data artifacts for custom_task_portland
# (wrapper pid=21844) Should transfer from custom_task_portland to gather_portland_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_seattle in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_seattle
# (wrapper pid=21844) Collaborator Seattle: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_seattle
# (wrapper pid=21844) Saved data artifacts for custom_task_seattle
# (wrapper pid=21844) Should transfer from custom_task_seattle to gather_seattle_results
# Saving data artifacts for gather_seattle_results
# Saved data artifacts for gather_seattle_results
# Sending state from aggregator to collaborators
# Next function = gather_chandler_results
#
# Calling gather_chandler_results
# Saving data artifacts for gather_chandler_results
# Saved data artifacts for gather_chandler_results
# Sending state from aggregator to collaborators
# Next function = gather_bangalore_results
#
# Calling gather_bangalore_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_chandler in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_chandler
# (wrapper pid=21844) Collaborator Chandler: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_chandler
# (wrapper pid=21844) Saved data artifacts for custom_task_chandler
# (wrapper pid=21844) Should transfer from custom_task_chandler to gather_chandler_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_bangalore in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_bangalore
# (wrapper pid=21844) Collaborator Bangalore: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_bangalore
# (wrapper pid=21844) Saved data artifacts for custom_task_bangalore
# (wrapper pid=21844) Should transfer from custom_task_bangalore to gather_bangalore_results
# Saving data artifacts for gather_bangalore_results
# Saved data artifacts for gather_bangalore_results
#
# Calling combine
# The results from each of the collaborators are: [0, 1, 2, 3]
# Their average = 1.5
#
# Starting round 1...
# Saving data artifacts for combine
# Saved data artifacts for combine
# Sending state from aggregator to collaborators
# Next function = gather_portland_results
#
# Calling gather_portland_results
# Saving data artifacts for gather_portland_results
# Saved data artifacts for gather_portland_results
# Sending state from aggregator to collaborators
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_portland in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_portland
# (wrapper pid=21844) Collaborator Portland: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_portland
# (wrapper pid=21844) Saved data artifacts for custom_task_portland
# (wrapper pid=21844) Should transfer from custom_task_portland to gather_portland_results
# Next function = gather_seattle_results
#
# Calling gather_seattle_results
# Saving data artifacts for gather_seattle_results
# Saved data artifacts for gather_seattle_results
# Sending state from aggregator to collaborators
# Next function = gather_chandler_results
#
# Calling gather_chandler_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_seattle in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_seattle
# (wrapper pid=21844) Collaborator Seattle: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_seattle
# (wrapper pid=21844) Saved data artifacts for custom_task_seattle
# (wrapper pid=21844) Should transfer from custom_task_seattle to gather_seattle_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_chandler in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_chandler
# (wrapper pid=21844) Collaborator Chandler: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_chandler
# (wrapper pid=21844) Saved data artifacts for custom_task_chandler
# (wrapper pid=21844) Should transfer from custom_task_chandler to gather_chandler_results
# Saving data artifacts for gather_chandler_results
# Saved data artifacts for gather_chandler_results
# Sending state from aggregator to collaborators
# Next function = gather_bangalore_results
#
# Calling gather_bangalore_results
# Saving data artifacts for gather_bangalore_results
# Saved data artifacts for gather_bangalore_results
#
# Calling combine
# The results from each of the collaborators are: [0, 1, 2, 3]
# Their average = 1.5
#
# Starting round 2...
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_bangalore in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_bangalore
# (wrapper pid=21844) Collaborator Bangalore: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_bangalore
# (wrapper pid=21844) Saved data artifacts for custom_task_bangalore
# (wrapper pid=21844) Should transfer from custom_task_bangalore to gather_bangalore_results
# Saving data artifacts for combine
# Saved data artifacts for combine
# Sending state from aggregator to collaborators
# Next function = gather_portland_results
#
# Calling gather_portland_results
# Saving data artifacts for gather_portland_results
# Saved data artifacts for gather_portland_results
# Sending state from aggregator to collaborators
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_portland in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_portland
# (wrapper pid=21844) Collaborator Portland: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_portland
# (wrapper pid=21844) Saved data artifacts for custom_task_portland
# (wrapper pid=21844) Should transfer from custom_task_portland to gather_portland_results
# Next function = gather_seattle_results
#
# Calling gather_seattle_results
# Saving data artifacts for gather_seattle_results
# Saved data artifacts for gather_seattle_results
# Sending state from aggregator to collaborators
# Next function = gather_chandler_results
#
# Calling gather_chandler_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_seattle in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_seattle
# (wrapper pid=21844) Collaborator Seattle: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_seattle
# (wrapper pid=21844) Saved data artifacts for custom_task_seattle
# (wrapper pid=21844) Should transfer from custom_task_seattle to gather_seattle_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_chandler in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_chandler
# (wrapper pid=21844) Collaborator Chandler: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_chandler
# (wrapper pid=21844) Saved data artifacts for custom_task_chandler
# (wrapper pid=21844) Should transfer from custom_task_chandler to gather_chandler_results
# Saving data artifacts for gather_chandler_results
# Saved data artifacts for gather_chandler_results
# Sending state from aggregator to collaborators
# Next function = gather_bangalore_results
#
# Calling gather_bangalore_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_bangalore in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_bangalore
# (wrapper pid=21844) Collaborator Bangalore: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_bangalore
# (wrapper pid=21844) Saved data artifacts for custom_task_bangalore
# (wrapper pid=21844) Should transfer from custom_task_bangalore to gather_bangalore_results
# Saving data artifacts for gather_bangalore_results
# Saved data artifacts for gather_bangalore_results
#
# Calling combine
# The results from each of the collaborators are: [0, 1, 2, 3]
# Their average = 1.5
#
# Starting round 3...
# Saving data artifacts for combine
# Saved data artifacts for combine
# Sending state from aggregator to collaborators
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_portland in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_portland
# (wrapper pid=21844) Collaborator Portland: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_portland
# Next function = gather_portland_results
#
# Calling gather_portland_results
# Saving data artifacts for gather_portland_results
# Saved data artifacts for gather_portland_results
# Sending state from aggregator to collaborators
# Next function = gather_seattle_results
#
# Calling gather_seattle_results
# (wrapper pid=21844) Saved data artifacts for custom_task_portland
# (wrapper pid=21844) Should transfer from custom_task_portland to gather_portland_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_seattle in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_seattle
# (wrapper pid=21844) Collaborator Seattle: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_seattle
# (wrapper pid=21844) Saved data artifacts for custom_task_seattle
# (wrapper pid=21844) Should transfer from custom_task_seattle to gather_seattle_results
# Saving data artifacts for gather_seattle_results
# Saved data artifacts for gather_seattle_results
# Sending state from aggregator to collaborators
# Next function = gather_chandler_results
#
# Calling gather_chandler_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_chandler in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_chandler
# (wrapper pid=21844) Collaborator Chandler: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_chandler
# (wrapper pid=21844) Saved data artifacts for custom_task_chandler
# (wrapper pid=21844) Should transfer from custom_task_chandler to gather_chandler_results
# Saving data artifacts for gather_chandler_results
# Saved data artifacts for gather_chandler_results
# Sending state from aggregator to collaborators
# Next function = gather_bangalore_results
#
# Calling gather_bangalore_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_bangalore in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_bangalore
# (wrapper pid=21844) Collaborator Bangalore: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_bangalore
# (wrapper pid=21844) Saved data artifacts for custom_task_bangalore
# (wrapper pid=21844) Should transfer from custom_task_bangalore to gather_bangalore_results
# Saving data artifacts for gather_bangalore_results
# Saved data artifacts for gather_bangalore_results
#
# Calling combine
# The results from each of the collaborators are: [0, 1, 2, 3]
# Their average = 1.5
#
# Starting round 4...
# Saving data artifacts for combine
# Saved data artifacts for combine
# Sending state from aggregator to collaborators
# Next function = gather_portland_results
#
# Calling gather_portland_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_portland in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_portland
# (wrapper pid=21844) Collaborator Portland: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_portland
# (wrapper pid=21844) Saved data artifacts for custom_task_portland
# (wrapper pid=21844) Should transfer from custom_task_portland to gather_portland_results
# Saving data artifacts for gather_portland_results
# Saved data artifacts for gather_portland_results
# Sending state from aggregator to collaborators
# Next function = gather_seattle_results
#
# Calling gather_seattle_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_seattle in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_seattle
# (wrapper pid=21844) Collaborator Seattle: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_seattle
# (wrapper pid=21844) Saved data artifacts for custom_task_seattle
# (wrapper pid=21844) Should transfer from custom_task_seattle to gather_seattle_results
# Saving data artifacts for gather_seattle_results
# Saved data artifacts for gather_seattle_results
# Sending state from aggregator to collaborators
# Next function = gather_chandler_results
#
# Calling gather_chandler_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_chandler in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_chandler
# (wrapper pid=21844) Collaborator Chandler: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_chandler
# (wrapper pid=21844) Saved data artifacts for custom_task_chandler
# (wrapper pid=21844) Should transfer from custom_task_chandler to gather_chandler_results
# Saving data artifacts for gather_chandler_results
# Saved data artifacts for gather_chandler_results
# Sending state from aggregator to collaborators
# Next function = gather_bangalore_results
#
# Calling gather_bangalore_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_bangalore in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_bangalore
# (wrapper pid=21844) Collaborator Bangalore: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_bangalore
# (wrapper pid=21844) Saved data artifacts for custom_task_bangalore
# (wrapper pid=21844) Should transfer from custom_task_bangalore to gather_bangalore_results
# Saving data artifacts for gather_bangalore_results
# Saved data artifacts for gather_bangalore_results
#
# Calling combine
# The results from each of the collaborators are: [0, 1, 2, 3]
# Their average = 1.5
#
# Starting round 5...
# Saving data artifacts for combine
# Saved data artifacts for combine
# Sending state from aggregator to collaborators
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_portland in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_portland
# (wrapper pid=21844) Collaborator Portland: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_portland
# Next function = gather_portland_results
#
# Calling gather_portland_results
# Saving data artifacts for gather_portland_results
# (wrapper pid=21844) Saved data artifacts for custom_task_portland
# (wrapper pid=21844) Should transfer from custom_task_portland to gather_portland_results
# Saved data artifacts for gather_portland_results
# Sending state from aggregator to collaborators
# Next function = gather_seattle_results
#
# Calling gather_seattle_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_seattle in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_seattle
# (wrapper pid=21844) Collaborator Seattle: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_seattle
# (wrapper pid=21844) Saved data artifacts for custom_task_seattle
# (wrapper pid=21844) Should transfer from custom_task_seattle to gather_seattle_results
# Saving data artifacts for gather_seattle_results
# Saved data artifacts for gather_seattle_results
# Sending state from aggregator to collaborators
# Next function = gather_chandler_results
#
# Calling gather_chandler_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_chandler in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_chandler
# (wrapper pid=21844) Collaborator Chandler: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_chandler
# (wrapper pid=21844) Saved data artifacts for custom_task_chandler
# (wrapper pid=21844) Should transfer from custom_task_chandler to gather_chandler_results
# Saving data artifacts for gather_chandler_results
# Saved data artifacts for gather_chandler_results
# Sending state from aggregator to collaborators
# Next function = gather_bangalore_results
#
# Calling gather_bangalore_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_bangalore in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_bangalore
# (wrapper pid=21844) Collaborator Bangalore: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_bangalore
# (wrapper pid=21844) Saved data artifacts for custom_task_bangalore
# (wrapper pid=21844) Should transfer from custom_task_bangalore to gather_bangalore_results
# Saving data artifacts for gather_bangalore_results
# Saved data artifacts for gather_bangalore_results
#
# Calling combine
# The results from each of the collaborators are: [0, 1, 2, 3]
# Their average = 1.5
#
# Starting round 6...
# Saving data artifacts for combine
# Saved data artifacts for combine
# Sending state from aggregator to collaborators
# Next function = gather_portland_results
#
# Calling gather_portland_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_portland in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_portland
# (wrapper pid=21844) Collaborator Portland: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_portland
# (wrapper pid=21844) Saved data artifacts for custom_task_portland
# (wrapper pid=21844) Should transfer from custom_task_portland to gather_portland_results
# Saving data artifacts for gather_portland_results
# Saved data artifacts for gather_portland_results
# Sending state from aggregator to collaborators
# Next function = gather_seattle_results
#
# Calling gather_seattle_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_seattle in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_seattle
# (wrapper pid=21844) Collaborator Seattle: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_seattle
# (wrapper pid=21844) Saved data artifacts for custom_task_seattle
# (wrapper pid=21844) Should transfer from custom_task_seattle to gather_seattle_results
# Saving data artifacts for gather_seattle_results
# Saved data artifacts for gather_seattle_results
# Sending state from aggregator to collaborators
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_chandler in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_chandler
# (wrapper pid=21844) Collaborator Chandler: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_chandler
# (wrapper pid=21844) Saved data artifacts for custom_task_chandler
# (wrapper pid=21844) Should transfer from custom_task_chandler to gather_chandler_results
# Next function = gather_chandler_results
#
# Calling gather_chandler_results
# Saving data artifacts for gather_chandler_results
# Saved data artifacts for gather_chandler_results
# Sending state from aggregator to collaborators
# Next function = gather_bangalore_results
#
# Calling gather_bangalore_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_bangalore in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_bangalore
# (wrapper pid=21844) Collaborator Bangalore: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_bangalore
# (wrapper pid=21844) Saved data artifacts for custom_task_bangalore
# (wrapper pid=21844) Should transfer from custom_task_bangalore to gather_bangalore_results
# Saving data artifacts for gather_bangalore_results
# Saved data artifacts for gather_bangalore_results
#
# Calling combine
# The results from each of the collaborators are: [0, 1, 2, 3]
# Their average = 1.5
#
# Starting round 7...
# Saving data artifacts for combine
# Saved data artifacts for combine
# Sending state from aggregator to collaborators
# Next function = gather_portland_results
#
# Calling gather_portland_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_portland in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_portland
# (wrapper pid=21844) Collaborator Portland: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_portland
# (wrapper pid=21844) Saved data artifacts for custom_task_portland
# (wrapper pid=21844) Should transfer from custom_task_portland to gather_portland_results
# Saving data artifacts for gather_portland_results
# Saved data artifacts for gather_portland_results
# Sending state from aggregator to collaborators
# Next function = gather_seattle_results
#
# Calling gather_seattle_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_seattle in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_seattle
# (wrapper pid=21844) Collaborator Seattle: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_seattle
# (wrapper pid=21844) Saved data artifacts for custom_task_seattle
# (wrapper pid=21844) Should transfer from custom_task_seattle to gather_seattle_results
# Saving data artifacts for gather_seattle_results
# Saved data artifacts for gather_seattle_results
# Sending state from aggregator to collaborators
# Next function = gather_chandler_results
#
# Calling gather_chandler_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_chandler in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_chandler
# (wrapper pid=21844) Collaborator Chandler: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_chandler
# (wrapper pid=21844) Saved data artifacts for custom_task_chandler
# (wrapper pid=21844) Should transfer from custom_task_chandler to gather_chandler_results
# Saving data artifacts for gather_chandler_results
# Saved data artifacts for gather_chandler_results
# Sending state from aggregator to collaborators
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_bangalore in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_bangalore
# (wrapper pid=21844) Collaborator Bangalore: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_bangalore
# Next function = gather_bangalore_results
#
# Calling gather_bangalore_results
# (wrapper pid=21844) Saved data artifacts for custom_task_bangalore
# (wrapper pid=21844) Should transfer from custom_task_bangalore to gather_bangalore_results
# Saving data artifacts for gather_bangalore_results
# Saved data artifacts for gather_bangalore_results
#
# Calling combine
# The results from each of the collaborators are: [0, 1, 2, 3]
# Their average = 1.5
#
# Starting round 8...
# Saving data artifacts for combine
# Saved data artifacts for combine
# Sending state from aggregator to collaborators
# Next function = gather_portland_results
#
# Calling gather_portland_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_portland in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_portland
# (wrapper pid=21844) Collaborator Portland: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_portland
# (wrapper pid=21844) Saved data artifacts for custom_task_portland
# (wrapper pid=21844) Should transfer from custom_task_portland to gather_portland_results
# Saving data artifacts for gather_portland_results
# Saved data artifacts for gather_portland_results
# Sending state from aggregator to collaborators
# Next function = gather_seattle_results
#
# Calling gather_seattle_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_seattle in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_seattle
# (wrapper pid=21844) Collaborator Seattle: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_seattle
# (wrapper pid=21844) Saved data artifacts for custom_task_seattle
# (wrapper pid=21844) Should transfer from custom_task_seattle to gather_seattle_results
# Saving data artifacts for gather_seattle_results
# Saved data artifacts for gather_seattle_results
# Sending state from aggregator to collaborators
# Next function = gather_chandler_results
#
# Calling gather_chandler_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_chandler in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_chandler
# (wrapper pid=21844) Collaborator Chandler: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_chandler
# (wrapper pid=21844) Saved data artifacts for custom_task_chandler
# (wrapper pid=21844) Should transfer from custom_task_chandler to gather_chandler_results
# Saving data artifacts for gather_chandler_results
# Saved data artifacts for gather_chandler_results
# Sending state from aggregator to collaborators
# Next function = gather_bangalore_results
#
# Calling gather_bangalore_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_bangalore in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_bangalore
# (wrapper pid=21844) Collaborator Bangalore: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_bangalore
# (wrapper pid=21844) Saved data artifacts for custom_task_bangalore
# (wrapper pid=21844) Should transfer from custom_task_bangalore to gather_bangalore_results
# Saving data artifacts for gather_bangalore_results
# Saved data artifacts for gather_bangalore_results
#
# Calling combine
# The results from each of the collaborators are: [0, 1, 2, 3]
# Their average = 1.5
#
# Starting round 9...
# Saving data artifacts for combine
# Saved data artifacts for combine
# Sending state from aggregator to collaborators
# Next function = gather_portland_results
#
# Calling gather_portland_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_portland in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_portland
# (wrapper pid=21844) Collaborator Portland: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_portland
# (wrapper pid=21844) Saved data artifacts for custom_task_portland
# (wrapper pid=21844) Should transfer from custom_task_portland to gather_portland_results
# Saving data artifacts for gather_portland_results
# Saved data artifacts for gather_portland_results
# Sending state from aggregator to collaborators
# Next function = gather_seattle_results
#
# Calling gather_seattle_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_seattle in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_seattle
# (wrapper pid=21844) Collaborator Seattle: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_seattle
# (wrapper pid=21844) Saved data artifacts for custom_task_seattle
# (wrapper pid=21844) Should transfer from custom_task_seattle to gather_seattle_results
# Saving data artifacts for gather_seattle_results
# Saved data artifacts for gather_seattle_results
# Sending state from aggregator to collaborators
# Next function = gather_chandler_results
#
# Calling gather_chandler_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_chandler in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_chandler
# (wrapper pid=21844) Collaborator Chandler: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_chandler
# (wrapper pid=21844) Saved data artifacts for custom_task_chandler
# (wrapper pid=21844) Should transfer from custom_task_chandler to gather_chandler_results
# Saving data artifacts for gather_chandler_results
# Saved data artifacts for gather_chandler_results
# Sending state from aggregator to collaborators
# Next function = gather_bangalore_results
#
# Calling gather_bangalore_results
# (wrapper pid=21844)
# (wrapper pid=21844) Running custom_task_bangalore in a new process
# (wrapper pid=21844)
# (wrapper pid=21844) Calling custom_task_bangalore
# (wrapper pid=21844) Collaborator Bangalore: performing custom task
# (wrapper pid=21844) Saving data artifacts for custom_task_bangalore
# (wrapper pid=21844) Saved data artifacts for custom_task_bangalore
# (wrapper pid=21844) Should transfer from custom_task_bangalore to gather_bangalore_results
# Saving data artifacts for gather_bangalore_results
# Saved data artifacts for gather_bangalore_results
#
# Calling combine
# The results from each of the collaborators are: [0, 1, 2, 3]
# Their average = 1.5
# Saving data artifacts for combine
# Saved data artifacts for combine
#
# Calling end
# This is the end of the flow
# Reached end of the flow with collaborator results = [0, 1, 2, 3]

# %% [markdown]
# Now that the flow has completed, you can use metaflow tooling to look at the data associated with the experiment

# %%
run_id = vflow._run_id

# %%
import metaflow

# %%
from metaflow import Metaflow, Flow, Task, Step

# %%
m = Metaflow()
list(m)
# Out:
# [Flow('VerticalFlow')]

# %%
f = Flow('VerticalFlow').latest_run

# %%
f
# Out:
# Run('VerticalFlow/1666307288836294')

# %%
list(f)
# Out:
# [Step('VerticalFlow/1666307288836294/combine'),
#  Step('VerticalFlow/1666307288836294/gather_bangalore_results'),
#  Step('VerticalFlow/1666307288836294/custom_task_bangalore'),
#  Step('VerticalFlow/1666307288836294/gather_chandler_results'),
#  Step('VerticalFlow/1666307288836294/custom_task_chandler'),
#  Step('VerticalFlow/1666307288836294/gather_seattle_results'),
#  Step('VerticalFlow/1666307288836294/custom_task_seattle'),
#  Step('VerticalFlow/1666307288836294/gather_portland_results'),
#  Step('VerticalFlow/1666307288836294/custom_task_portland'),
#  Step('VerticalFlow/1666307288836294/start')]

# %%
s = Step(f'VerticalFlow/{run_id}/combine')

# %%
s
# Out:
# Step('VerticalFlow/1666307288836294/combine')

# %%
list(s)
# Out:
# [Task('VerticalFlow/1666307288836294/combine/91'),
#  Task('VerticalFlow/1666307288836294/combine/82'),
#  Task('VerticalFlow/1666307288836294/combine/73'),
#  Task('VerticalFlow/1666307288836294/combine/64'),
#  Task('VerticalFlow/1666307288836294/combine/55'),
#  Task('VerticalFlow/1666307288836294/combine/46'),
#  Task('VerticalFlow/1666307288836294/combine/37'),
#  Task('VerticalFlow/1666307288836294/combine/28'),
#  Task('VerticalFlow/1666307288836294/combine/19'),
#  Task('VerticalFlow/1666307288836294/combine/10')]

# %%
t = Task(f'VerticalFlow/{run_id}/combine/91')

# %%
t
# Out:
# Task('VerticalFlow/1666307015070672/combine/91')

# %%
t.data
# Out:
# <MetaflowData: collaborators, next_collaborator, results, round>

# %%
t.data.round
# Out:
# 10
